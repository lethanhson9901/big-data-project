# %%
import pandas as pd
import datetime
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt 
from pandas.plotting import lag_plot
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Hàm kiểm tra Dickey-Fuller với dữ liệu

# %%
def check_stationarity(df):
    ts_data = df.copy()
    ts_data.dropna(inplace=True)

    # Rolling statistics
    roll_mean = ts_data.rolling(30).mean()
    roll_std = ts_data.rolling(5).std()
    
    # Plot rolling statistics
    plt.figure(figsize=(20,10))
    plt.subplot(211)
    plt.plot(ts_data, color='black', label='Original Data')
    plt.plot(roll_mean, color='red', label='Rolling Mean(30 days)')
    plt.legend()
    plt.subplot(212)
    plt.plot(roll_std, color='green', label='Rolling Std Dev(5 days)')
    plt.legend()
    
    # Dickey-Fuller test
    print('Dickey-Fuller test results\n')
    df_test = adfuller(ts_data, regresults=False)
    test_result = pd.Series(df_test[0:4], index=['Test Statistic','p-value','# of lags','# of obs'])
    print(test_result)
    for k,v in df_test[4].items():
        print('Critical value at %s: %1.5f' %(k,v))

# %% [markdown]
# Hàm tính toán và biểu diễn Autocorrelation cũng như partialAutocorrelation

# %%
def autocorrelation_partialAutocorrelation(df):
    df_acf = acf(df.Mean)
    df_pacf = pacf(df.Mean)

    fig1 = plt.figure(figsize=(20,10))
    ax1 = fig1.add_subplot(211)
    #significance limit region
    fig1 = sm.graphics.tsa.plot_acf(df_acf, ax=ax1)

    ax2 = fig1.add_subplot(212)
    #significance limit region
    fig1 = sm.graphics.tsa.plot_pacf(df_pacf, ax=ax2)

# %% [markdown]
# # Thực hiện đọc dữ liệu từ hdfs

# %% [markdown]
# Dữ liệu đã được lưu trữ trên hdfs, hiện tại ta cần sử dụng pyspark để đọc dữ liệu ra và xử lý. Cụm spark đã được bật, ta có thể xem thông tin của cả cụm trên web ui host post của spark-master là 0.0.0.0:8080 (truy cập qua localhost) hoặc 172.19.0.4:8080 (truy cập qua ip của container trong docker, xem thông tin bằng lệnh docker network inspect).

# %%
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
from IPython.display import Image

# %%
#Truy cập vào master của cụm tại địa chỉ 172.19.0.4:7077 với tên chương trình là Stock_price_analysis
spark = SparkSession.builder.master("spark://0.0.0.0:7077").appName("Stock_price_analysis").getOrCreate()

# %% [markdown]
# Ta có thể  truy cập vào địa chỉ web ui của spark-master để xem thông tin của chương trình đang chạy

# %%
Image("spark_app.png")

# %% [markdown]
# Tiếp theo ta sẽ sử dụng spark session vừa tạo để truy cập vào hdfs và lấy dữ liệu ra để sử lý. Cụ thể ta sẽ truy cập vào địa chỉ của namenode trên hdfs là namenode:9000

# %%
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
from pyspark.sql.functions import expr, col, column
sc = SparkContext('local')
spark = SparkSession(sc)

# %% [markdown]
# ## Đưa dữ liệu vào để biểu diễn
#
# Ta lấy dữ liệu dataframe từ spark như thông thường.
#
# Ở đây ta so sánh dữ liệu chứng khoán của 5 công ty lớn:
#
# #### Facebook (mã FB)
#
# #### Alibaba (mã BABA)
#
# #### Apple (mã AAPL)
#
# #### Cloudflare (mã NET)
#
# #### Zoom meeting (mã ZM)

# %%
df_FB = spark.read.format("csv").option("header", "true")\
.option("inferSchema", "true").load("./Data_stock/datack/stock_market_data-FB_2020-12-16.csv")

df_BABA = spark.read.format("csv").option("header", "true")\
.option("inferSchema", "true").load("./Data_stock/datack/stock_market_data-BABA_2020-12-15.csv")

df_AAPL = spark.read.format("csv").option("header", "true")\
.option("inferSchema", "true").load("./Data_stock/datack/stock_market_data-AAPL_2020-12-16.csv")

df_NET = spark.read.format("csv").option("header", "true")\
.option("inferSchema", "true").load("./Data_stock/datack/stock_market_data-NET_2020-12-16.csv")

df_ZM = spark.read.format("csv").option("header", "true")\
.option("inferSchema", "true").load("./Data_stock/datack/stock_market_data-ZM_2020-12-16.csv")

# %% [markdown]
# Sau khi lấy dữ liệu, ta thực hiện việc thêm cột Mean để tìm trung bình của mã chứng khoán trong ngày.
#
# Từ đó ta vẽ được biểu đồ để so sánh các mã chứng khoán.

# %%
from pyspark.sql.functions import year

df_FBmean = df_FB.withColumn("Mean", expr('(High+Low)/2')).select("Date","Mean")
df_BABAmean = df_BABA.withColumn("Mean", expr('(High+Low)/2')).select("Date","Mean")
df_AAPLmean = df_AAPL.withColumn("Mean", expr('(High+Low)/2')).select("Date","Mean").filter(year("Date") > 2010)
df_NETmean = df_NET.withColumn("Mean", expr('(High+Low)/2')).select("Date","Mean")
df_ZMmean = df_ZM.withColumn("Mean", expr('(High+Low)/2')).select("Date","Mean")

# %% [markdown]
# Để dễ sử dụng thư viện đồ thị matplotlib, ta chuyển các dữ liệu dataframes về dạng pandas.

# %%
df_FBmean = df_FBmean.toPandas()
df_BABAmean = df_BABAmean.toPandas()
df_AAPLmean = df_AAPLmean.toPandas()
df_NETmean = df_NETmean.toPandas()
df_ZMmean = df_ZMmean.toPandas()

# %% [markdown]
# Kết quả so sánh chỉ số trung bình trong ngày của các mã nói trên trong đồ thị

# %%
ax = df_FBmean.plot(x='Date', y= 'Mean', label='Facebook', figsize=(16,6))
ax = df_BABAmean.plot(ax=ax, x= 'Date', y= 'Mean',label='Alibaba')
ax = df_NETmean.plot(ax=ax, x= 'Date', y= 'Mean',label='Cloudfare')
ax = df_ZMmean.plot(ax=ax, x= 'Date', y= 'Mean',label='Zoom')
df_AAPLmean.plot(ax=ax, x= 'Date', y= 'Mean',label='Apple')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Dùng mô hình học máy để dự đoán tình hình chứng khoán

# %% [markdown]
# Trong phần này chúng em sẽ tính giá trị trung bình của cổ phiếu công ty Gabelli Equity Trust Inc (mã là GAB). Rồi sử dụng một mô hình học máy đơn giản để dự đoán giá cổ phiếu trung bình của công ty. Chúng em dùng các thông tin từ trước năm 2020 cho việc training và thông tin của năm 2020 cho việc testing.

# %%
df = spark.read.format("csv")\
.option("header", "true")\
.option("inferSchema", "true")\
.load("hdfs://namenode:9000/user/root/datack/stock_market_data-GAB_2020-12-15.csv")

# %%
df.show(5)
# Out:
# +----+----------+----+-----+----+-----+
# | _c0|      Date|Open| High| Low|Close|
# +----+----------+----+-----+----+-----+
# |5314|2020-12-14|6.33| 6.35|6.13| 6.16|
# |5313|2020-12-11|6.36| 6.37|6.22| 6.26|
# |5312|2020-12-10|6.42| 6.47|6.38| 6.41|
# |5311|2020-12-09|6.73| 6.84|6.64| 6.72|
# |5310|2020-12-08|6.63|6.765| 6.6| 6.74|
# +----+----------+----+-----+----+-----+
# only showing top 5 rows

# %%
from pyspark.sql.functions import expr, col, column
df = df.withColumn("Mean", expr('(High+Low)/2'))  #Thêm một cột giá trị mean ( được tính bằng trung bình của low và high)

# %%
df.show(5)
# Out:
# +----+----------+----+-----+----+-----+-----------------+
# | _c0|      Date|Open| High| Low|Close|             Mean|
# +----+----------+----+-----+----+-----+-----------------+
# |5314|2020-12-14|6.33| 6.35|6.13| 6.16|             6.24|
# |5313|2020-12-11|6.36| 6.37|6.22| 6.26|            6.295|
# |5312|2020-12-10|6.42| 6.47|6.38| 6.41|            6.425|
# |5311|2020-12-09|6.73| 6.84|6.64| 6.72|             6.74|
# |5310|2020-12-08|6.63|6.765| 6.6| 6.74|6.682499999999999|
# +----+----------+----+-----+----+-----+-----------------+
# only showing top 5 rows

# %%
asc_df = df.sort(df.Date.asc()) #Sắp xếp các cột theo tứ tự tăng dần của thời gian

# %%
asc_df.show(5)
# Out:
# +---+----------+-----+-----+-----+-----+------------------+
# |_c0|      Date| Open| High|  Low|Close|              Mean|
# +---+----------+-----+-----+-----+-----+------------------+
# |  0|1999-11-01|11.69|11.75|11.56|11.56|11.655000000000001|
# |  1|1999-11-02|11.63|11.75|11.63|11.75|11.690000000000001|
# |  2|1999-11-03|11.75|11.75|11.69|11.75|11.719999999999999|
# |  3|1999-11-04|11.75|11.88|11.69|11.81|            11.785|
# |  4|1999-11-05|11.94| 12.0|11.88|11.88|11.940000000000001|
# +---+----------+-----+-----+-----+-----+------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import year
df_test = asc_df.filter(year("Date") > 2019) #tách ra tập test là tập gồm thông tin của năm 2020

# %%
df_test.show(5)
# Out:
# +----+----------+----+----+----+-----+------------------+
# | _c0|      Date|Open|High| Low|Close|              Mean|
# +----+----------+----+----+----+-----+------------------+
# |5074|2020-01-02| 6.1|6.14|6.07|  6.1|             6.105|
# |5075|2020-01-03|6.06|6.08|6.04| 6.08|6.0600000000000005|
# |5076|2020-01-06|6.07| 6.1|6.06| 6.09|              6.08|
# |5077|2020-01-07|6.07| 6.1|6.07| 6.08|             6.085|
# |5078|2020-01-08|6.08|6.12|6.07| 6.11| 6.095000000000001|
# +----+----------+----+----+----+-----+------------------+
# only showing top 5 rows

# %%
df_train = asc_df.subtract(df_test)   #tách ra tập train
df_train.count()
# Out:
# 5074

# %%
df_train = df_train.sort(df_train.Date.asc())   #sắp xếp lại tập train
df_train.show(5)
# Out:
# +---+----------+-----+-----+-----+-----+------------------+
# |_c0|      Date| Open| High|  Low|Close|              Mean|
# +---+----------+-----+-----+-----+-----+------------------+
# |  0|1999-11-01|11.69|11.75|11.56|11.56|11.655000000000001|
# |  1|1999-11-02|11.63|11.75|11.63|11.75|11.690000000000001|
# |  2|1999-11-03|11.75|11.75|11.69|11.75|11.719999999999999|
# |  3|1999-11-04|11.75|11.88|11.69|11.81|            11.785|
# |  4|1999-11-05|11.94| 12.0|11.88|11.88|11.940000000000001|
# +---+----------+-----+-----+-----+-----+------------------+
# only showing top 5 rows

# %%
dataset_train = df_train.toPandas()

# %%
# !pip install keras
# Out:
# Collecting keras
#   Downloading Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.8/site-packages (from keras) (5.3.1)
# Requirement already satisfied: scipy>=0.14 in /opt/conda/lib/python3.8/site-packages (from keras) (1.5.3)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.8/site-packages (from keras) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.8/site-packages (from keras) (1.19.4)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.8/site-packages (from keras) (1.19.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from h5py->keras) (1.15.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.8/site-packages (from keras) (1.19.4)
# Installing collected packages: keras
# Successfully installed keras-2.4.3

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.4.0-cp38-cp38-manylinux2010_x86_64.whl (394.8 MB)
#      |████████████████████████████████| 394.8 MB 2.7 kB/s eta 0:00:018  |▊                               | 9.4 MB 7.0 MB/s eta 0:00:55     |█▎                              | 15.6 MB 691 kB/s eta 0:09:09     |██████▊                         | 82.8 MB 4.8 MB/s eta 0:01:05     |████████▍                       | 102.9 MB 1.0 MB/s eta 0:04:47     |████████▉                       | 108.4 MB 2.5 MB/s eta 0:01:56     |████████▉                       | 109.5 MB 2.5 MB/s eta 0:01:56     |█████████                       | 112.3 MB 2.3 MB/s eta 0:02:01     |███████████████▏                | 186.5 MB 1.5 MB/s eta 0:02:23     |██████████████████              | 222.5 MB 3.3 MB/s eta 0:00:53     |██████████████████              | 223.0 MB 3.3 MB/s eta 0:00:53     |████████████████████▋           | 253.7 MB 2.0 MB/s eta 0:01:13     |████████████████████████▎       | 299.4 MB 5.3 MB/s eta 0:00:19     |██████████████████████████▋     | 328.1 MB 1.1 MB/s eta 0:01:03     |███████████████████████████▍    | 338.0 MB 5.3 MB/s eta 0:00:11ta 0:04:42     |██████████████████████████████▊ | 378.5 MB 73 kB/s eta 0:03:42     |███████████████████████████████▉| 392.7 MB 3.2 MB/s eta 0:00:01     |████████████████████████████████| 393.7 MB 3.0 MB/s eta 0:00:01
# Requirement already satisfied: protobuf>=3.9.2 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: wheel~=0.35 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: numpy~=1.19.2 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (1.19.4)
# Collecting absl-py~=0.10
#   Downloading absl_py-0.11.0-py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 4.1 MB/s eta 0:00:01
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: wheel~=0.35 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 480 kB/s eta 0:00:011
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Collecting grpcio~=1.32.0
#   Downloading grpcio-1.32.0-cp38-cp38-manylinux2014_x86_64.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 3.5 MB/s eta 0:00:01
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Collecting h5py~=2.10.0
#   Downloading h5py-2.10.0-cp38-cp38-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 125 kB/s eta 0:00:01
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: numpy~=1.19.2 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (1.19.4)
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 176 kB/s eta 0:00:01
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: numpy~=1.19.2 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (1.19.4)
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 502 kB/s eta 0:00:01
# Requirement already satisfied: numpy~=1.19.2 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (1.19.4)
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from protobuf>=3.9.2->tensorflow) (49.6.0.post20201009)
# Collecting tensorboard~=2.4
#   Downloading tensorboard-2.4.0-py3-none-any.whl (10.6 MB)
#      |████████████████████████████████| 10.6 MB 2.2 MB/s eta 0:00:01
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: protobuf>=3.9.2 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: numpy~=1.19.2 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (1.19.4)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from protobuf>=3.9.2->tensorflow) (49.6.0.post20201009)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (2.25.0)
# Requirement already satisfied: wheel~=0.35 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (0.36.0)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.24.0-py2.py3-none-any.whl (114 kB)
#      |████████████████████████████████| 114 kB 3.6 MB/s eta 0:00:01
# Requirement already satisfied: six~=1.15.0 in /opt/conda/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from protobuf>=3.9.2->tensorflow) (49.6.0.post20201009)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.0-py3-none-any.whl (12 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.2-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.3-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 747 kB/s eta 0:00:01
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 3.5 MB/s eta 0:00:01
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 605 kB/s eta 0:00:01
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2020.11.8)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (3.0.4)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (3.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (2.25.0)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.6-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 512 kB/s eta 0:00:01
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.7.0-py3-none-any.whl (779 kB)
#      |████████████████████████████████| 779 kB 3.5 MB/s eta 0:00:01
# Collecting tensorflow-estimator<2.5.0,>=2.4.0rc0
#   Downloading tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 3.4 MB/s eta 0:00:01
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 4.0 MB/s eta 0:00:01
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Building wheels for collected packages: termcolor, wrapt
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=b539a148317bc6f4f018a7988c9a162a457d041c166102e8318b4b4c004b1ac9
#   Stored in directory: /home/jovyan/.cache/pip/wheels/a0/16/9c/5473df82468f958445479c59e784896fa24f4a5fc024b0f501
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp38-cp38-linux_x86_64.whl size=81781 sha256=8a775d2b3e656937cf28d97ed954cf2a606055fa7a7607de71230e434a295f7a
#   Stored in directory: /home/jovyan/.cache/pip/wheels/5f/fd/9e/b6cf5890494cb8ef0b5eaff72e5d55a70fb56316007d6dfe73
# Successfully built termcolor wrapt
# Installing collected packages: pyasn1, rsa, pyasn1-modules, cachetools, requests-oauthlib, google-auth, werkzeug, tensorboard-plugin-wit, markdown, grpcio, google-auth-oauthlib, absl-py, wrapt, termcolor, tensorflow-estimator, tensorboard, opt-einsum, keras-preprocessing, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# Successfully installed absl-py-0.11.0 astunparse-1.6.3 cachetools-4.2.0 flatbuffers-1.12 gast-0.3.3 google-auth-1.24.0 google-auth-oauthlib-0.4.2 google-pasta-0.2.0 grpcio-1.32.0 h5py-2.10.0 keras-preprocessing-1.1.2 markdown-3.3.3 opt-einsum-3.3.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.6 tensorboard-2.4.0 tensorboard-plugin-wit-1.7.0 tensorflow-2.4.0 tensorflow-estimator-2.4.0 termcolor-1.1.0 werkzeug-1.0.1 wrapt-1.12.1

# %%
# Import những thư viện cần thiết
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os.path
from os import path
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Thuc hien scale du lieu gia ve khoang 0,1
training_set = dataset_train.iloc[:, 6:7].values
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %% [markdown]
# Tạo dữ liệu train, X = 60 time steps, Y =  1 time step, có nghĩa lấy dữ liệu của 60 ngày trước để dự đoán cho ngày tiếp theo hay có thể hiểu là lấy 60 ngày trước làm đầu vào, và đầu ra của mô hình sẽ là ngày tiếp theo

# %%
# Tạo dữ liệu train 
X_train = []
y_train = []
no_of_sample = len(training_set)

for i in range(60, no_of_sample):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
# Xây dựng model LSTM
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 1))
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Nếu tồn tại model thì load lại nếu không thì thực hiện train 
if path.exists("mymodel.h5"):
    regressor.load_weights("mymodel.h5")
else:
    regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
    regressor.save("mymodel.h5")

# %%
dataset_test = df_test.toPandas()
real_stock_price = dataset_test.iloc[:, 6:7].values

# %%
# Tiến hành dự đoán 
dataset_total = pd.concat((dataset_train['Close'], dataset_test['Close']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)

X_test = []
no_of_sample = len(inputs)

for i in range(60, no_of_sample):
    X_test.append(inputs[i-60:i, 0])

X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
# Ve bieu do gia that va gia du doan
plt.figure(figsize=(16,9))
plt.plot(real_stock_price, color = 'red', label = 'Real GAB Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted GAB Stock Price')
plt.title('GAB Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('GAB Stock Price')
plt.legend()
plt.show()

# %%
spark.stop()

# %%
Image("spark_st.png")
